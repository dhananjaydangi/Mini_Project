# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\dhana\OneDrive\Desktop\Data Thinker\Project 6 (Udemy)\Udemy_Courses.csv" , parse_dates=["published_timestamp"])

# %%
df.head(10)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# 5    1122832  #6 Piano Hand Coordination: Play Open 10 Balla...     True
# 6    1123184  #7 Piano Hand Coordination: Play Piano Runs in...     True
# 7     768028  * An Integrated Approach to the Fundamentals o...     True
# 8     206592  :::Beginners Guide To Creating Amazing Images ...     True
# 9     738910  [Value Investing] Where White People Keep Thei...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# ...

# %%
df.tail(10)
# Out:
#       course_id                                       course_title  is_paid  \
# 3672    1031698                        You Can Play Jazz Saxophone     True
# 3673      79364                       Your Business by the Numbers     True
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   datetime64[ns, UTC]
#  10  subject              3682 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), int64(4), object(5)
# memory usage: 291.4+ KB

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    3676
# True        6
# Name: count, dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.duplicated().value_counts()
# Out:
# False    3676
# Name: count, dtype: int64

# %%
grouped_data = df.groupby("subject")

# %%
grouped_data["course_title"].count()
# Out:
# subject
# Business Finance       1195
# Graphic Design          602
# Musical Instruments     680
# Web Development        1199
# Name: course_title, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
sns.countplot(x="subject" , data=df)
plt.xlabel("subject" , fontsize=13)
plt.ylabel("count" , fontsize=13)
plt.xticks(rotation=60)
plt.show()

# %%
df["level"].value_counts()
# Out:
# level
# All Levels            1928
# Beginner Level        1269
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
df["content_duration"].unique()
# Out:
# array(['1.5 ', '1 hour', '37 mins', '44 mins', '5.5 ', '4 ', '31 mins',
#        '2.5 ', '6.5 ', '3 ', '8.5 ', '4.5 ', '9.5 ', '2 ', '3.5 ', '9 ',
#        '5 ', '36 mins', '16 ', '32 mins', '14 ', '35 mins', '6 ',
#        '41 mins', '7.5 ', '14.5 ', '24.5 ', '33 mins', '29 ', '13.5 ',
#        '42 mins', '33 ', '12.5 ', '8 ', '7 ', '34 mins', '11.5 ', '62 ',
#        '12 ', '39 mins', '19 mins', '15.5 ', '10.5 ', '21 ', '68.5 ',
#        '19.5 ', '20.5 ', '22 ', '10 ', '38 mins', '43 mins', '40 mins',
#        '24 ', '13 ', '31.5 ', '44.5 ', '17.5 ', '48.5 ', '60 ', '11 ',
#        '27.5 ', '18.5 ', '25.5 ', '22.5 ', '16.5 ', '30 mins', '57 ',
#        '45 ', '20 ', '39 ', '34 ', '25 ', '26 ', '29.5 ', '15 ', '37.5 ',
#        '71.5 ', '47 ', '18 ', '38 ', '28.5 ', '8 mins', '32.5 ', '31 ',
#        '17 ', '27 mins', '29 mins', '46.5 ', '43.5 ', '66.5 ', '26.5 ',
#        '0', '30 ', '30.5 ', '19 ', '23 ', '23.5 ', '24 questions',
# ...

# %%
df["content_duration"]=df["content_duration"].str.replace("hours" , "")

# %%
df["content_duration"]=df["content_duration"].str.replace("mins" , "")
df["content_duration"]=df["content_duration"].str.replace("hour" , "")
df["content_duration"]=df["content_duration"].str.replace(" questions" , "")

# %%
df
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...
